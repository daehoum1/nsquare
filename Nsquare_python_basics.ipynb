# %% [markdown]
# > ### Nsquare
#
# # Python Basics

# %% [markdown]
# 0. 시작
# 1. 변수, 자료형, 연산자
# 2. 조건문
# 3. 반복문
# 4. 함수
# 5. 리스트
# 6. 튜플
# 7. 딕셔너리
# 8. 객체 지향 프로그래밍 맛보기

# %% [markdown]
# ## 노트북 사용 방법
#
# - 코드 셀을 선택한 뒤 **Shift + Enter**를 누르면 실행됩니다.
# - 실행 결과는 코드 바로 아래에 출력됩니다.
#
# 이 노트북에서는 `input()`을 거의 사용하지 않았습니다.
# 수업 중 모든 셀이 멈추지 않고 실행되도록, 입력값은 코드 안의 변수로 미리 정해 두었습니다.

# %% [markdown]
# ---
#
# # 0부. 기초 출력/주석 사용하기
#
#
# Colab이나 Jupyter Notebook에서는 코드 셀을 실행하면 바로 아래에 결과가 나타납니다.

# %% [markdown]
# ## 예제 0-1. 가장 기본적인 출력
#
# `print()`는 화면에 값을 출력하는 함수입니다.
# 수업 초반에는 계산 결과가 제대로 나왔는지 확인하기 위해 `print()`를 자주 사용합니다.

# %%
print("안녕하세요. 파이썬 실습을 시작합니다.")
print("코드 셀을 실행하면 결과가 아래에 출력됩니다.")

# %% [markdown]
# ## 예제 0-2. 주석 사용하기
#
# 주석은 코드에 설명을 남기는 방법입니다.
# 파이썬은 `#` 뒤에 있는 문장을 코드로 실행하지 않습니다.

# %%
# 이 줄은 주석입니다. 실행되지 않습니다.
# 주석은 코드의 의도를 설명할 때 사용합니다.

print("이 줄은 실제로 실행됩니다.")

# %% [markdown]
# ---
#
# # 1부. 변수와 자료형
#
# 변수는 데이터를 저장해 두는 이름입니다.
# 파이썬에서는 `=` 기호를 사용해 오른쪽 값을 왼쪽 변수 이름에 저장합니다.
#
# 수학에서 `=`는 같다는 뜻이지만, 프로그래밍에서 `=`는 보통 **대입**을 의미합니다.

# %% [markdown]
# ## 예제 1-1. 변수에 값 저장하기
#
# 아래 코드는 `weight`라는 변수에 숫자 값을 저장한 뒤 출력합니다.
# 그 다음 같은 변수에 다른 값을 다시 저장해 봅니다.

# %%
weight = 72
print("처음 저장된 몸무게:", weight)

# 같은 변수에 새로운 값을 넣으면 이전 값이 바뀝니다.
weight = 70
print("변경 후 몸무게:", weight)

# %% [markdown]
# ## 예제 1-2. 변수 여러 개 사용하기
#
# 변수는 한 개만 사용하는 것이 아니라, 필요한 만큼 여러 개를 만들 수 있습니다.
# 이름을 잘 지으면 코드가 무엇을 의미하는지 더 쉽게 읽을 수 있습니다.

# %%
name = "이준호"
age = 21
city = "서울"
vis = 1.5

print("이름:", name)
print("나이:", age)
print("도시:", city)
print("시력:", vis)

# %% [markdown]
# ## 예제 1-3. 기본 자료형 확인하기
#
# 자료형은 데이터의 종류입니다.
# 대표적으로 다음 네 가지를 자주 사용합니다.
#
# | 자료형 | 의미 | 예시 |
# |---|---|---|
# | `int` | 정수 | `10`, `-3` |
# | `float` | 실수 | `3.14`, `0.5` |
# | `str` | 문자열 | `"Python"` |
# | `bool` | 참/거짓 | `True`, `False` |
#
# `type()`을 사용하면 값의 자료형을 확인할 수 있습니다.

# %%
student_count = 30      # 정수 int
average_score = 87.5    # 실수 float
course_name = "Python"  # 문자열 str
is_open = True          # 불리언 bool

print(student_count, type(student_count))
print(average_score, type(average_score))
print(course_name, type(course_name))
print(is_open, type(is_open))

# %% [markdown]
# ## 예제 1-4. 숫자형 자료를 이용한 계산
#
# 정수와 실수는 계산에 사용할 수 있습니다.
# 파이썬은 사칙연산뿐 아니라 제곱, 나머지, 몫 계산도 지원합니다.

# %%
a = 10
b = 3

print("더하기:", a + b)
print("빼기:", a - b)
print("곱하기:", a * b)
print("나누기:", a / b)
print("몫:", a // b)
print("나머지:", a % b)
print("제곱:", a ** b)

# %% [markdown]
# ## 예제 1-5. 문자열 다루기
#
# 문자열은 글자 데이터를 저장하는 자료형입니다.
# 숫자처럼 더하기 기호를 사용할 수 있지만, 의미는 계산이 아니라 **문자열 연결**입니다.

# %%
first_name = "서준"
last_name = "김"
full_name = last_name + first_name

print(full_name)
print(full_name + "님, 안녕하세요.")

# %% [markdown]
# ## 예제 1-6. f-string으로 문장 만들기
#
# 문자열 안에 변수 값을 넣고 싶을 때 `f-string`을 자주 사용합니다.
# 문자열 앞에 `f`를 붙이고, 변수는 `{}` 안에 넣습니다.

# %%
name = "박준영"
age = 22
score = 91.5

message = f"{name} 학생은 {age}세이고, 시험 점수는 {score}점입니다."
print(message)

# %%
name = "박준영"
age = 22
score = 91.5

message = f"{name} 학생은 {age}세이고, 시험 점수는 {score}점입니다."
print(message)

# %% [markdown]
# ## 예제 1-7. 비교 연산자
#
# 비교 연산자는 두 값을 비교하고 결과로 `True` 또는 `False`를 반환합니다.
#
# | 연산자 | 의미 |
# |---|---|
# | `>` | 크다 |
# | `<` | 작다 |
# | `>=` | 크거나 같다 |
# | `<=` | 작거나 같다 |
# | `==` | 같다 |
# | `!=` | 같지 않다 |

# %%
score = 100

print("점수가 80보다 큰가?", score > 80)
print("점수가 90 이상인가?", score >= 90)
print("점수가 85와 같은가?", score == 85)
print("점수가 100이 아닌가?", score != 100)

# %% [markdown]
# ## 예제 1-8. 논리 연산자
#
# 논리 연산자는 여러 조건을 하나로 묶을 때 사용합니다.
#
# | 연산자 | 의미 |
# |---|---|
# | `and` | 두 조건이 모두 참일 때 참 |
# | `or` | 두 조건 중 하나라도 참이면 참 |
# | `not` | 참과 거짓을 반대로 바꿈 |

# %%
age = 20
has_ticket = True
has_coupon = False
points = 3500

can_enter = age >= 19 and has_ticket
can_discount = has_coupon or points >= 3000

print("입장 가능 여부:", can_enter)
print("할인 가능 여부:", can_discount)
print("쿠폰이 없는가?", not has_coupon)

# %% [markdown]
# ## 연습 1. 변수 값을 바꿔 보기
#
# 아래 코드에서 `my_name`, `my_age`, `my_score` 값을 바꿔 실행해 보세요.
# 변수 값을 바꾸면 출력 문장도 함께 바뀝니다.

# %%
my_name = "이름을 입력해보세요"
my_age = 20
my_score = 88.0

print(f"이름: {my_name}")
print(f"나이: {my_age}")
print(f"점수: {my_score}")
print(f"90점 이상인가요? {my_score >= 90}")

# %% [markdown]
# ---
#
# # 2부. 조건문
#
# 조건문은 어떤 조건이 참인지 거짓인지에 따라 실행할 코드를 선택하는 문법입니다.
#
# 기본 구조는 다음과 같습니다.
#
# ```python
# if 조건식:
#     조건식이 True일 때 실행할 코드
# ```
#
# 파이썬에서는 들여쓰기가 중요합니다.
# `if` 아래에서 실행될 코드는 반드시 일정하게 들여써야 합니다.

# %% [markdown]
# ## 예제 2-1. 가장 기본적인 if 문
#
# 온도가 25도 이상이면 안내 문장을 출력합니다.
# 조건이 `False`이면 들여쓰기 된 코드는 실행되지 않습니다.

# %%
temperature = 24

if temperature >= 25:
    print("날씨가 따뜻합니다.")
    print("가벼운 옷차림을 준비해도 좋습니다.")

print("이 문장은 조건문 밖에 있으므로 항상 실행됩니다.")

# %% [markdown]
# ## 들여쓰기 오류 예시
#
# 아래 코드는 일부러 실행하지 않는 설명용 코드입니다.
# `if` 문 아래 코드를 들여쓰지 않으면 오류가 발생합니다.
#
# ```python
# temperature = 26
#
# if temperature >= 25:
# print("날씨가 따뜻합니다.")  # 들여쓰기가 없어 오류 발생
# ```
#
# 파이썬에서는 중괄호 `{}` 대신 들여쓰기로 코드 블록을 구분합니다.

# %% [markdown]
# ## 예제 2-2. if / else 문
#
# `else`는 조건이 거짓일 때 실행되는 부분입니다.
# 두 가지 경우 중 하나를 선택해야 할 때 사용합니다.

# %%
score = 75

if score >= 60:
    print("통과입니다.")
else:
    print("재도전이 필요합니다.")

# %% [markdown]
# ## 예제 2-3. if / elif / else 문
#
# 조건이 여러 개일 때는 `elif`를 사용할 수 있습니다.
# 위에서 아래로 조건을 검사하고, 가장 먼저 참이 되는 블록만 실행합니다.

# %%
score = 97

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "D"

print("점수:", score)
print("등급:", grade)

# %% [markdown]
# ## 예제 2-4. 논리 연산자를 조건문에 사용하기
#
# 여러 기준을 함께 판단해야 할 때 `and`, `or`, `not`을 조건문 안에서 사용합니다.

# %%
age = 22
has_payment = True
has_coupon = False
points = 2500

if age >= 19 and has_payment:
    print("예약이 가능합니다.")
else:
    print("예약 조건을 확인해야 합니다.")

if has_coupon or points >= 3000:
    print("할인을 받을 수 있습니다.")
else:
    print("할인 조건에 해당하지 않습니다.")

# %% [markdown]
# ## 예제 2-5. 조건문으로 간단한 추천 만들기
#
# 조건문은 값을 분류하거나, 상황에 따라 다른 메시지를 출력할 때 자주 사용됩니다.
# 아래 예제는 걸음 수에 따라 활동 상태를 나누는 코드입니다.

# %%
steps = 7200

if steps >= 10000:
    status = "매우 활발"
elif steps >= 5000:
    status = "보통"
else:
    status = "활동량 부족"

print(f"오늘 걸음 수: {steps}보")
print(f"활동 상태: {status}")

# %% [markdown]
# ## 연습 2. 조건 바꿔 보기
#
# 아래 코드에서 `score` 값을 바꿔 보세요.
# 점수에 따라 출력되는 문장이 어떻게 달라지는지 확인합니다.

# %%
score = 71

if score >= 90:
    print("우수")
elif score >= 70:
    print("보통")
else:
    print("보충 필요")

# %% [markdown]
# ---
#
# # 3부. 반복문
#
# 반복문은 같은 작업을 여러 번 실행하는 문법입니다.
# 파이썬에서는 대표적으로 `for` 문과 `while` 문을 사용합니다.
#
# - `for`: 정해진 횟수만큼 반복하거나, 목록 안의 값을 하나씩 처리할 때 사용
# - `while`: 조건이 참인 동안 계속 반복할 때 사용

# %% [markdown]
# ## 예제 3-1. for 문과 range()
#
# `range(5)`는 0, 1, 2, 3, 4라는 숫자의 흐름을 만듭니다.
# 즉, 5번 반복하지만 숫자는 0부터 시작합니다.

# %%
print("**********")
for i in range(5):
    print("========")
    print("현재 i 값:", i)
    print("========")
print("***^_^***")

# %% [markdown]
# ## 예제 3-2. 1부터 10까지 더하기
#
# 반복문은 누적 계산에 자주 사용됩니다.
# `total = total + number`는 기존 `total`에 `number`를 더해 다시 `total`에 저장한다는 뜻입니다.

# %%
total = 0

for number in range(1, 11):
    total = total + number
    print(f"현재 숫자: {number}, 현재까지 합계: {total}")

print("최종 합계:", total)

# %% [markdown]
# ## 예제 3-3. 리스트를 직접 반복하기
#
# `range()` 대신 리스트를 `for` 문에 넣으면, 리스트 안의 항목이 하나씩 꺼내집니다.

# %%
fruits = ["사과", "귤", "포도", "딸기"]

for fruit in fruits:
    print(f"장바구니에 {fruit}가 있습니다.")

# %% [markdown]
# ## 예제 3-4. 반복문과 조건문 함께 사용하기
#
# 반복문으로 여러 값을 하나씩 확인하고, 조건문으로 필요한 값만 골라낼 수 있습니다.

# %%
scores = [58, 81, 94, 49, 73]

for score in scores:
    if score >= 60:
        print(score, "점: 통과")
    else:
        print(score, "점: 재도전")

# %% [markdown]
# ## 예제 3-5. while 문으로 목표 금액까지 저축하기
#
# `while` 문은 조건이 참인 동안 계속 반복합니다.
# 아래 예제에서는 저축액이 50,000원 미만인 동안 10,000원씩 저축합니다.

# %%
saving = 0
goal = 50000
week = 0

while saving < goal:
    week = week + 1
    saving = saving + 10000
    print(f"{week}주차 저축액: {saving}원")

print("목표 금액 달성")

# %% [markdown]
# ## 예제 3-6. 무한 반복을 피하는 방법
#
# `while` 문은 조건이 계속 참이면 끝나지 않습니다.
# 따라서 반복문 안에서 조건이 언젠가 거짓이 되도록 값을 바꿔야 합니다.
#
# 아래 예제에서는 `count`를 1씩 증가시키기 때문에 언젠가 `count < 3`이 거짓이 됩니다.

# %%
count = 0

while count < 3:
    print("현재 count:", count)
    count = count + 1

print("반복 종료")

# %% [markdown]
# ## 연습 3. 반복 횟수 바꿔 보기
#
# 아래 코드에서 `range(1, 6)`의 숫자를 바꿔 보세요.
# 반복 횟수와 출력 결과가 어떻게 달라지는지 확인합니다.

# %%
for number in range(1, 6):
    print(number, "번째 실행")

# %% [markdown]
# ---
#
# # 4부. 함수
#
# 함수는 여러 줄의 작업에 이름을 붙여 다시 사용할 수 있게 만든 코드 블록입니다.
# 반복되는 코드를 줄이고, 프로그램을 더 읽기 쉽게 만들 때 사용합니다.
#
# 기본 구조는 다음과 같습니다.
#
# ```python
# def 함수이름():
#     실행할 코드
# ```

# %% [markdown]
# ## 예제 4-1. 가장 간단한 함수
#
# 아래 함수는 실행할 때마다 안내 문장 두 줄을 출력합니다.

# %%
def show_start_message():
    print("실습을 시작합니다.")
    print("위에서 아래로 천천히 실행하세요.")

show_start_message()
show_start_message()

# %% [markdown]
# ## 예제 4-2. 매개변수와 인자
#
# 함수를 만들 때 입력값의 자리 이름을 **매개변수**라고 합니다.
# 함수를 사용할 때 실제로 넣는 값을 **인자**라고 합니다.
#
# 아래 함수에서 `name`, `age`는 매개변수입니다.
# `"박준영"`, `22`는 함수를 호출할 때 넣는 인자입니다.

# %%
def introduce(name, age):
    print(f"이름은 {name}입니다.")
    print(f"나이는 {age}세입니다.")

introduce("박준영", 22)
introduce("김서연", 20)

# %% [markdown]
# ## 예제 4-3. return으로 결과 돌려주기
#
# `return`은 함수 안에서 만든 결과를 함수 밖으로 돌려줍니다.
# 함수의 결과를 다른 계산에 계속 사용하려면 `return`이 필요합니다.

# %%
def add(a, b):
    result = a + b
    return result

answer = add(12, 18)
print("함수에서 반환된 값:", answer)
print("반환값에 5를 더한 값:", answer + 5)

# %% [markdown]
# ## 예제 4-4. print와 return의 차이
#
# `print()`는 화면에 보여주는 기능입니다.
# `return`은 값을 함수 밖으로 전달하는 기능입니다.
#
# 둘은 비슷해 보이지만 역할이 다릅니다.

# %%
def add_and_print(a, b):
    print(a + b)


def add_and_return(a, b):
    return a + b

printed_result = add_and_print(2, 3)
returned_result = add_and_return(2, 3)

print("print만 사용한 함수의 결과:", printed_result)
print("return을 사용한 함수의 결과:", returned_result)

# %% [markdown]
# `print`만 사용한 함수는 화면에는 값을 보여주지만, 함수 밖으로 실제 계산 결과를 넘기지는 않습니다.
# 그래서 `printed_result`에는 `None`이 저장됩니다.

# %% [markdown]
# ## 예제 4-5. 기본값 매개변수
#
# 기본값 매개변수는 함수 호출 시 값을 생략했을 때 자동으로 사용되는 값입니다.

# %%
def greet(name, message="안녕하세요"):
    print(f"{name}님, {message}.")

# message를 생략하면 기본값이 사용됩니다.
greet("박준영")

# message를 직접 넣으면 직접 넣은 값이 사용됩니다.
greet("김서연", "좋은 아침입니다")

# %% [markdown]
# ## 예제 4-6. 함수로 평균과 등급 계산하기
#
# 함수는 계산 규칙을 하나로 묶을 때 유용합니다.
# 아래 예제에서는 평균을 계산하는 함수와 등급을 판단하는 함수를 따로 만듭니다.

# %%
def calculate_average(scores):
    total = sum(scores)
    count = len(scores)
    return total / count


def make_grade(average):
    if average >= 90:
        return "A"
    elif average >= 80:
        return "B"
    elif average >= 70:
        return "C"
    else:
        return "D"

scores = [82, 90, 86]
average = calculate_average(scores)
grade = make_grade(average)

print("점수 목록:", scores)
print("평균:", average)
print("등급:", grade)

# %% [markdown]
# ## 연습 4. 함수 입력값 바꿔 보기
#
# 아래 코드에서 `prices` 값을 바꿔 실행해 보세요.
# 합계와 평균이 함께 바뀝니다.

# %%
def summarize_prices(prices):
    total = sum(prices)
    average = total / len(prices)
    return total, average

prices = [1500, 2400, 3200, 1900]
total_price, average_price = summarize_prices(prices)

print("가격 목록:", prices)
print("합계:", total_price)
print("평균:", average_price)

# %% [markdown]
# ---
#
# # 5부. 리스트
#
# 리스트는 여러 데이터를 순서대로 묶어 저장하는 자료형입니다.
# 리스트 안의 각 값은 위치 번호를 가지며, 이 번호를 **인덱스**라고 합니다.
#
# 파이썬의 인덱스는 1이 아니라 0부터 시작합니다.

# %% [markdown]
# ## 예제 5-1. 리스트 만들기와 append()
#
# 리스트는 처음부터 값을 넣어 만들 수도 있고, 빈 리스트로 만든 뒤 값을 하나씩 추가할 수도 있습니다.
# `append()`는 리스트의 맨 뒤에 값을 추가하는 메서드입니다.

# %%
empty_list = []
numbers = [1, 2, 3, 4]

print("빈 리스트:", empty_list)
print("숫자 리스트:", numbers)

empty_list.append("공책")
empty_list.append("볼펜")
empty_list.append("지우개")

print("추가 후 리스트:", empty_list)

# %% [markdown]
# ## 예제 5-2. 리스트에 자주 쓰는 함수
#
# 리스트 전체를 대상으로 길이, 최댓값, 최솟값, 합계를 계산할 수 있습니다.

# %%
scores = [86, 77, 93, 68, 98]

print("점수 목록:", scores)
print("개수:", len(scores))
print("최댓값:", max(scores))
print("최솟값:", min(scores))
print("합계:", sum(scores))
print("평균:", sum(scores) / len(scores))

# %% [markdown]
# ## 예제 5-3. 리스트 인덱싱
#
# 인덱싱은 리스트에서 특정 위치의 값 하나를 꺼내는 방법입니다.
# 첫 번째 값의 인덱스는 0입니다.

# %%
subjects = ["국어", "영어", "수학", "과학", "역사"]

print("전체 과목:", subjects)
print("0번 인덱스:", subjects[0])
print("2번 인덱스:", subjects[2])
print("마지막 항목:", subjects[-1])

# %% [markdown]
# ## 예제 5-4. 리스트 슬라이싱
#
# 슬라이싱은 리스트에서 연속된 일부 구간을 잘라 가져오는 방법입니다.
#
# ```python
# 리스트[시작:끝]
# ```
#
# 끝 위치의 값은 포함되지 않습니다.
# 예를 들어 `days[1:4]`는 1번, 2번, 3번 인덱스를 가져옵니다.

# %%
days = ["월", "화", "수", "목", "금", "토", "일"]

weekday = days[0:5]
weekend = days[5:7]
middle = days[1:4]

print("평일:", weekday)
print("주말:", weekend)
print("1번부터 3번까지:", middle)

# %% [markdown]
# ## 예제 5-5. 리스트 값 변경하기
#
# 리스트는 생성한 뒤에도 내부 값을 바꿀 수 있습니다.
# 인덱스로 위치를 지정한 뒤 새 값을 대입하면 됩니다.

# %%
fruits = ["사과", "바나나", "포도"]
print("변경 전:", fruits)

fruits[1] = "귤"
print("변경 후:", fruits)

# %% [markdown]
# ## 예제 5-6. 리스트 항목 삭제하기
#
# - `remove(값)`: 특정 값을 찾아 삭제합니다.
# - `pop(인덱스)`: 특정 위치의 값을 삭제하면서 그 값을 반환합니다.
# - `pop()`처럼 인덱스를 생략하면 마지막 항목을 삭제합니다.

# %%
items = ["공책", "볼펜", "지우개", "형광펜"]
print("처음 목록:", items)

items.remove("지우개")
print("remove 후:", items)

removed_item = items.pop(0)
print("pop으로 꺼낸 값:", removed_item)
print("pop 후 목록:", items)

# %% [markdown]
# ## 예제 5-7. 리스트 순회하기
#
# 반복문을 사용하면 리스트 안의 모든 값을 차례대로 처리할 수 있습니다.

# %%
subjects = ["국어", "영어", "수학", "과학"]

for subject in subjects:
    print(f"{subject} 과목을 확인합니다.")

# %% [markdown]
# ## 예제 5-8. sorted()와 sort()의 차이
#
# 둘 다 정렬에 사용하지만 차이가 있습니다.
#
# - `sorted(리스트)`: 원본은 유지하고 정렬된 새 리스트를 만듭니다.
# - `리스트.sort()`: 원본 리스트 자체를 정렬합니다.

# %%
scores = [74, 86, 63, 96]

sorted_scores = sorted(scores)
print("원본 scores:", scores)
print("sorted 결과:", sorted_scores)

scores.sort()
print("sort 실행 후 원본 scores:", scores)

# %% [markdown]
# ## 예제 5-9. 리스트와 조건문을 함께 사용하기
#
# 리스트에 들어 있는 값 중 조건에 맞는 값만 따로 모을 수 있습니다.
# 아래 예제에서는 80점 이상인 점수만 `high_scores`에 추가합니다.

# %%
scores = [58, 84, 93, 49, 75, 87]
high_scores = []

for score in scores:
    if score >= 80:
        high_scores.append(score)

print("전체 점수:", scores)
print("80점 이상 점수:", high_scores)

# %% [markdown]
# ## 연습 5. 리스트 수정해 보기
#
# 아래 코드에서 `shopping_list`에 항목을 추가하거나 삭제해 보세요.

# %%
shopping_list = ["우유", "달걀", "식빵"]

shopping_list.append("바나나")
shopping_list.remove("식빵")

print("최종 장보기 목록:", shopping_list)

# %% [markdown]
# ---
#
# # 6부. 튜플
#
# 튜플은 여러 값을 순서대로 묶어 저장한다는 점에서 리스트와 비슷합니다.
# 하지만 튜플은 한 번 만든 뒤 내부 값을 바꿀 수 없습니다.
#
# 값이 바뀌면 안 되는 정보를 보관할 때 사용할 수 있습니다.

# %% [markdown]
# ## 예제 6-1. 튜플 만들기와 인덱싱
#
# 튜플도 리스트처럼 인덱싱과 슬라이싱이 가능합니다.

# %%
point = (3, 5)
weekend = ("토", "일")

print("좌표:", point)
print("x 좌표:", point[0])
print("y 좌표:", point[1])
print("주말:", weekend)

# %% [markdown]
# ## 예제 6-2. 튜플은 값 변경이 불가능함
#
# 튜플의 값을 바꾸려고 하면 오류가 발생합니다.
# 아래 코드는 오류를 일부러 확인하기 위해 `try-except`로 감쌌습니다.

# %%
location = ("서울", "시청역")

try:
    location[0] = "대전"
except TypeError as error:
    print("튜플은 내부 값을 바꿀 수 없습니다.")
    print("오류 메시지:", error)

# %% [markdown]
# ## 예제 6-3. 튜플을 사용하는 상황
#
# 아래 예제에서는 색상 정보를 튜플로 저장합니다.
# 색상처럼 하나의 묶음으로 다루고, 실수로 바뀌면 곤란한 값에는 튜플을 사용할 수 있습니다.

# %%
red_color = (255, 0, 0)
green_color = (0, 255, 0)
blue_color = (0, 0, 255)

print("빨강 RGB:", red_color)
print("초록 RGB:", green_color)
print("파랑 RGB:", blue_color)

# %% [markdown]
# ---
#
# # 7부. 딕셔너리
#
# 딕셔너리는 값을 순서 번호가 아니라 **키**로 찾는 자료형입니다.
#
# ```python
# 딕셔너리 = {
#     키1: 값1,
#     키2: 값2
# }
# ```
#
# 리스트가 `0번`, `1번` 같은 위치로 값을 찾는다면, 딕셔너리는 `"이름"`, `"나이"` 같은 이름표로 값을 찾습니다.

# %% [markdown]
# ## 예제 7-1. 딕셔너리 만들기와 값 접근
#
# 아래 예제에서는 학생 정보를 딕셔너리로 저장합니다.

# %%
student = {
    "name": "이준호",
    "age": 21,
    "city": "서울"
}

print("전체 딕셔너리:", student)
print("이름:", student["name"])
print("나이:", student["age"])
print("도시:", student["city"])

# %% [markdown]
# ## 예제 7-2. 딕셔너리 항목 추가와 수정
#
# 존재하지 않는 키에 값을 넣으면 새 항목이 추가됩니다.
# 이미 존재하는 키에 값을 넣으면 기존 값이 수정됩니다.

# %%
menu = {
    "김밥": 4000,
    "라면": 5000
}

print("처음 메뉴:", menu)

# 새 키 추가
menu["우동"] = 6000
print("우동 추가 후:", menu)

# 기존 키 값 수정
menu["라면"] = 5500
print("라면 가격 수정 후:", menu)

# %% [markdown]
# ## 예제 7-3. keys(), values(), items()
#
# 딕셔너리는 키, 값, 키-값 쌍을 따로 꺼내 볼 수 있습니다.

# %%
student = {
    "name": "박준영",
    "age": 22,
    "major": "전자공학",
    "score": 91
}

print("키 목록:", student.keys())
print("값 목록:", student.values())
print("키-값 쌍:", student.items())

# %% [markdown]
# ## 예제 7-4. 딕셔너리 반복문
#
# `items()`를 사용하면 키와 값을 함께 꺼내서 반복할 수 있습니다.

# %%
student = {
    "name": "박준영",
    "age": 22,
    "score": 91
}

for key, value in student.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 예제 7-5. 리스트 안에 딕셔너리 넣기
#
# 여러 명의 학생 정보를 다룰 때는 리스트와 딕셔너리를 함께 사용할 수 있습니다.
# 각 학생은 딕셔너리이고, 여러 학생을 리스트에 담는 방식입니다.

# %%
students = [
    {"name": "박준영", "score": 87},
    {"name": "김서연", "score": 93},
    {"name": "최민재", "score": 78}
]

for student in students:
    print(f"{student['name']} 학생의 점수는 {student['score']}점입니다.")

# %% [markdown]
# ## 예제 7-6. 딕셔너리와 조건문 함께 사용하기
#
# 딕셔너리 안의 값을 기준으로 조건을 판단할 수 있습니다.

# %%
students = [
    {"name": "박준영", "score": 87},
    {"name": "김서연", "score": 93},
    {"name": "최민재", "score": 78}
]

for student in students:
    if student["score"] >= 90:
        result = "우수"
    elif student["score"] >= 80:
        result = "보통 이상"
    else:
        result = "보충 필요"

    print(f"{student['name']}: {result}")

# %% [markdown]
# ## 연습 7. 딕셔너리 항목 추가하기
#
# 아래 코드에서 `profile` 딕셔너리에 새로운 정보를 추가해 보세요.
# 예를 들어 `"hobby"`, `"favorite_food"` 같은 키를 추가할 수 있습니다.

# %%
profile = {
    "name": "이준호",
    "age": 21
}

profile["city"] = "서울"
profile["hobby"] = "영화 감상"

print(profile)

# %% [markdown]
# ---
#
# # 8부. 객체 지향 프로그래밍 맛보기
#
# 파이썬에서 리스트, 문자열, 딕셔너리 같은 자료형은 모두 객체로 다룰 수 있습니다.
# 객체는 크게 두 가지를 가질 수 있습니다.
#
# - **속성**: 객체가 가지고 있는 정보
# - **메서드**: 객체가 수행할 수 있는 기능
#
# 예를 들어 리스트의 `append()`는 리스트 객체가 제공하는 메서드입니다.

# %% [markdown]
# ## 예제 8-1. 이미 사용하고 있던 메서드 확인하기
#
# 문자열, 리스트, 딕셔너리에는 각각 자주 사용하는 메서드가 있습니다.

# %%
text = "python"
print("대문자로 변환:", text.upper())
print("첫 글자만 대문자로:", text.capitalize())

numbers = [4, 2, 1]
numbers.append(3)
print("append 후 리스트:", numbers)

student = {"name": "박준영", "score": 91}
print("딕셔너리 키:", student.keys())

# %% [markdown]
# ## 예제 8-2. 클래스와 객체
#
# 클래스는 어떤 정보와 기능을 가질지 정해 둔 틀입니다.
# 객체는 그 틀을 바탕으로 실제로 만들어진 하나의 데이터입니다.
#
# 아래 예제에서는 `Student`라는 클래스를 만들고, 학생 객체를 생성합니다.

# %%
class Student:
    def __init__(self, name, scores):
        # self.name과 self.scores는 객체가 가지는 속성입니다.
        self.name = name
        self.scores = scores

    def average(self):
        # average는 객체가 수행할 수 있는 메서드입니다.
        return sum(self.scores) / len(self.scores)

    def show_summary(self):
        print(f"{self.name} 학생의 평균 점수는 {self.average():.1f}점입니다.")

student_a = Student("박준영", [82, 91, 86])
student_b = Student("김서연", [94, 89, 93])

student_a.show_summary()
student_b.show_summary()

# %% [markdown]
# ## 예제 8-3. 객체마다 다른 값 가질 수 있음
#
# 같은 `Student` 클래스로 만든 객체라도 내부 속성 값은 서로 다를 수 있습니다.
# 이 점이 클래스와 객체를 구분할 때 중요합니다.

# %%
print("student_a의 이름:", student_a.name)
print("student_a의 점수:", student_a.scores)
print("student_a의 평균:", student_a.average())

print("student_b의 이름:", student_b.name)
print("student_b의 점수:", student_b.scores)
print("student_b의 평균:", student_b.average())

# %% [markdown]
# ## NumPy 전에 객체 지향을 살짝 보는 이유
#
# 다음 단계에서 사용할 NumPy 배열도 단순한 숫자 묶음이 아니라 하나의 객체처럼 다루어집니다.
# 배열은 다음과 같은 정보를 가지고, 여러 기능도 제공합니다.
#
# - 모양: 몇 행, 몇 열인지
# - 자료형: 정수인지, 실수인지
# - 크기: 원소가 몇 개인지
# - 기능: 합계, 평균, 형태 변경 등
#
# 지금은 클래스를 깊게 외우기보다, **데이터와 기능이 하나의 대상에 묶일 수 있다**는 감각을 잡는 것이 중요합니다.
